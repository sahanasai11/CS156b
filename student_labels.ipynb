# %%
import pandas as pd
import numpy
from numpy import asarray
import PIL
from PIL import Image

# %%
train = pd.read_csv('/groups/CS156b/data/student_labels/train.csv')

test_ids = pd.read_csv('/groups/CS156b/data/student_labels/test_ids.csv')

solution_ids = pd.read_csv('/groups/CS156b/data/student_labels/solution_ids.csv')

# %%
# POSSIBLE TODO: DECOMPRESS IMAGES

# %%
# Use subset of the data for models

num_train = 100
num_test = 50

train_sub = train.sample(n=num_train)
test_sub = test_ids.sample(n=num_test)
solution_ids_sub = solution_ids.sample(n=num_test)

# %%
train_sub.head()
# Out:
#         Unnamed: 0                                     Path     Sex  Age  \
# 133090      167295  train/pid09325/study6/view1_frontal.jpg    Male   58
# 56257        70884  train/pid44519/study2/view2_lateral.jpg    Male   70
# 120637      151555  train/pid02745/study3/view1_frontal.jpg  Female   29
# 133985      168414  train/pid11017/study1/view1_frontal.jpg  Female   75
# 148271      186146  train/pid11739/study1/view1_frontal.jpg  Female   61
#
#        Frontal/Lateral AP/PA  No Finding  Enlarged Cardiomediastinum  \
# 133090         Frontal    AP        -1.0                         1.0
# 56257          Lateral   NaN        -1.0                         0.0
# 120637         Frontal    AP        -1.0                         NaN
# 133985         Frontal    AP        -1.0                        -1.0
# 148271         Frontal    AP        -1.0                         NaN
#
#         Cardiomegaly  Lung Opacity  Lung Lesion  Edema  Consolidation  \
# 133090           0.0           1.0          NaN    NaN            NaN
# 56257            NaN           0.0          NaN    NaN            0.0
# 120637           NaN           1.0          NaN    NaN            0.0
# 133985           NaN           NaN          NaN    NaN            1.0
# 148271          -1.0           NaN          NaN    NaN           -1.0
#
#         Pneumonia  Atelectasis  Pneumothorax  Pleural Effusion  Pleural Other  \
# 133090        0.0          0.0          -1.0               NaN            NaN
# 56257         NaN          1.0           NaN               NaN            NaN
# 120637        NaN          0.0           NaN               NaN            NaN
# 133985        0.0          NaN           NaN               0.0            NaN
# 148271        NaN          NaN           NaN               NaN            NaN
#
#         Fracture  Support Devices
# 133090       NaN              NaN
# 56257        1.0              1.0
# 120637       NaN              1.0
# 133985       NaN              1.0
# 148271       1.0              NaN

# %%
# Convert all training images into numpy arrays

train_imgs = []
init_path = '/groups/CS156b/data/'

for i, row in train_sub.iterrows():
    temp_img = Image.open(init_path + row['Path'])
    train_imgs.append(asarray(temp_img))

# %%
test_imgs = []
init_path = '/groups/CS156b/data/'

for i, row in test_sub.iterrows():
    temp_img = Image.open(init_path + row['Path'])
    test_imgs.append(asarray(temp_img))

# %%
solution_imgs = []
init_path = '/groups/CS156b/data/'

for i, row in solution_ids_sub.iterrows():
    temp_img = Image.open(init_path + row['Path'])
    solution_imgs.append(asarray(temp_img))
